# %% [markdown]
# ![Noteable.ac.uk Banner](https://github.com/jstix/mr-noteable/blob/master/Banner%20image/1500x500.jfif?raw=true)

# %% [markdown]
# # Computing without coding

# %% [markdown]
# ## Legend

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     In <b> blue</b>, the <b> instructions </b> and <b> goals </b> are highlighted.
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-success">
#     In <b> green</b>, the <b> information </b> is highlighted.
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#     In <b> yellow</b>, the <b> exercises </b> are highlighted.
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-danger">
#     In <b> red</b>, the <b> error </b> and <b> alert messages </b> are highlighted.
# </div>

# %% [markdown]
# ## Instructions

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <ul>
#         <li> Click <b> Run </b> on each cell to go through the code in each cell. This will take you through the cell and print out the results. </li>
#         <li> If you wish to see all the outputs at once in the whole notebook, just click <b> Cell </b> and then <b> Run All</b>. </li>
#         <li> Do not forget to import <b> all </b> the pictures into the same file, otherwise the images <b> will not be printed out! </b>
#     </ul>
# </div>

# %% [markdown]
# ## Objectives

# %% [markdown]
# <div class = "alert alert-block alert-info">
# After this workshop, the student should get more familiar with the following topics: <br>
# <ul>
#     <li> printing basic statements and commands in Jupyter Notebook</li>
#     <li> performing basic arithmetic calculations in Python</li>
#     <li> improving an existent model of the code</li>
#     <li> recognizing and checking variable types in Python </li>
#     <li> using the <b> if </b> statement for basic operations
# </ul>
#
# <b> These objectives are in agreement with the National 3 Scottish Curriculum for high-school students. </b> <br> <br> <b> Note: </b> For most of the workshop, the student will be given some coding examples. In some cases, the student will have to code himself/herself. The coding part is optional, but highly recommended to approach.
#
# </div>

# %% [markdown]
# ## Explore

# %% [markdown]
# <div class = "alert alert-block alert-warning">
# <b> Exercise: </b> we have some apples, pears and oranges and we want to sort them out properly. The apples should be in a basket, the pears should be in a different basket and the oranges should be in another basket. What you see below is the apple:
#     </div>

# %%
import PIL
from PIL import Image

apple = Image.open("apple.png")
apple = im_left.resize((150,150))

apple
# Out:
# <PIL.Image.Image image mode=P size=150x150 at 0x7FA27C0D1610>

# %% [markdown]
# Below is the pear:

# %%
pear = Image.open("pear.jpg")
pear = pear.resize((150,150))

pear
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FA27C0D1D10>

# %% [markdown]
# And below is the orange:

# %%
orange = Image.open("orange.jpg")
orange = orange.resize((150,150))

orange
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FA27C0C5C50>

# %% [markdown]
# <div class = "alert alert-block alert-warning">
# Suppose we have the following arrangement:
#     </div>

# %%
new_im = Image.new('RGB', (1050,150))

new_im.paste(apple, (0,0))
new_im.paste(pear, (150,0))
new_im.paste(pear, (300,0))
new_im.paste(orange, (450,0))
new_im.paste(apple, (600,0))
new_im.paste(orange, (750,0))
new_im.paste(apple, (900,0))

new_im
# Out:
# <PIL.Image.Image image mode=RGB size=1050x150 at 0x7FA27C0C58D0>

# %% [markdown]
# Let us go through each fruit, and sort them out.

# %% [markdown]
# <b> Fruit 1: </b> This is an apple:

# %%
apple
# Out:
# <PIL.Image.Image image mode=P size=150x150 at 0x7FA27C0D1610>

# %% [markdown]
# Put it into the basket for apples

# %% [markdown]
# <b> Fruit 2: </b> This is a pear

# %%
pear
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FA27C0D1D10>

# %% [markdown]
# Put it into the basket for pears.

# %% [markdown]
# <b> Fruit 3: </b> This is a pear

# %%
pear
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FA27C0D1D10>

# %% [markdown]
# Put it into the basket for pears

# %% [markdown]
# <div class = "alert alert-block alert-warning">
# <b> Challenge: </b> Can you use the same procedure for the other fruit?
#     </div>

# %% [markdown]
# In the end, the arrangement should look as below:

# %%
new_im = Image.new('RGB', (1050,150))

new_im.paste(apple, (0,0))
new_im.paste(apple, (150,0))
new_im.paste(apple, (300,0))
new_im.paste(pear, (450,0))
new_im.paste(pear, (600,0))
new_im.paste(orange, (750,0))
new_im.paste(orange, (900,0))

new_im
# Out:
# <PIL.Image.Image image mode=RGB size=1050x150 at 0x7FA27C0D9250>

# %% [markdown]
# <div class = "alert alert-block alert-success">
# <b> So what have we done exactly? </b> We went through a pile of fruits and checked which of them is an apple, which is a pear and which is an orange. We iterated through a list of objects, and grouped them into subclasses, in computer science terminology.
#     </div>

# %% [markdown]
# ### Number guessing:

# %% [markdown]
# <div class = "alert alert-block alert-warning">
# Let us take another example, to see how the computer would process the information. Furthermore, we will get familiar with some other terminologies such as <b> algorithm efficiency </b>, but we will take one thing at a time.
#     </div>

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#     We have now the following <b> game: </b> I take a number from 0 to 100 and you will have to guess it (let's just make it an integer, for easy life). Let us choose for example. number 47. The computer will ask the following:
#     </div>

# %%
print("What number are you thinking about?")
# Out:
# What number are you thinking about?

# %% [markdown]
# You answer at this will be the following:

# %%
print("Guess it!")
# Out:
# Guess it!

# %% [markdown]
# Then the computer starts doing its work: he can take the numbers from 0 to 100 in turn:

# %%
print("Is the number 1?")
# Out:
# Is the number 1?

# %%
print("Is the number 2?")
# Out:
# Is the number 2?

# %% [markdown]
# <div class = "alert alert-block alert-danger">
# The computer will reach indeed the number 100 in no time, but we still simulate its computational thinking. Moreover, for a person to take all the steps to 47 is too much... can we guess the number in a different way?
#     </div>

# %% [markdown]
# <div class = "alert alert-block alert-warning">
# <b> Do not scroll down and think about it! </b> Given any number between 0 and 100, can we find it within a reasonable number of steps (at most within 8 steps?) <b> Hint: </b> you are also allowed to ask if the number is smaller or greater than some specific value.
#     </div>

# %%
thincc = Image.open("thinkk.png")
thincc = thincc.resize((150,150))

thincc
# Out:
# <PIL.Image.Image image mode=RGBA size=150x150 at 0x7FA27C0C54D0>

# %% [markdown]
# Do you need more time?

# %%
new_im = Image.new('RGB', (1050,150))

new_im.paste(thincc, (0,0))
new_im.paste(thincc, (150,0))
new_im.paste(thincc, (300,0))
new_im.paste(thincc, (450,0))
new_im.paste(thincc, (600,0))
new_im.paste(thincc, (750,0))
new_im.paste(thincc, (900,0))

new_im
# Out:
# <PIL.Image.Image image mode=RGB size=1050x150 at 0x7FA27C0D9C50>

# %% [markdown]
# <div class = "alert alert-block alert-success">
# What if ask, firstly: is the number greater than 50? If the answer is yes, then we look at elements from 50 to 100. Otherwise, we look at numbers from 0 to 49.
#     </div>

# %% [markdown]
# <div class = "alert alert-block alert-success">
# Then, our next question could be (supposing we are looking for number 47): is our number smaller than 25? <b> No: </b> we are looking for numbers between 25 and 50.... do you notice how much the range of numbers to analyse has decreased? (4 times)..from 100 numbers, we analyze only 25 now.. This whole thinking goes on until you reach the final number (100 smaller than 128 which is $ 128 = 2^{7} $.  So in maximum 7 steps we find our number.
#     </div>

# %%
wow = Image.open("wow.png")
wow = wow.resize((150,150))

wow
# Out:
# <PIL.Image.Image image mode=RGBA size=150x150 at 0x7FA27C0E55D0>

# %% [markdown]
# <div class = "alert alert-block alert-success">
# We have just improved our rule to find the number: from random guessing or just enumerating numbers in ascending order, we found a better rule. This is what <b> algorithm efficiency </b> is about: asking the computer to work out a specific value in a shorter time. The above example is heavily used in computing science, and if you want to continue your studeis in computing, you will meet again many times this.
#     </div>

# %% [markdown]
# ## Take-away

# %% [markdown]
# <div class = "alert alert-block alert-success">
# This is the end of the workshop, well done for sticking up so far! No coding is required, however, feel free to use the notebook as you wish! Keep the images with the noteboook if you want to use it again. You are welcome at any time to use the notebook and code stuff here, just keep a fresh back-up
#     </div>

# %%
print("Bye bye! :D")
# Out:
# Bye bye! :D

# %% [markdown]
# ![Noteable license](https://github.com/jstix/mr-noteable/blob/master/Banner%20image/Screenshot%202021-03-05%20115453.png?raw=true)
