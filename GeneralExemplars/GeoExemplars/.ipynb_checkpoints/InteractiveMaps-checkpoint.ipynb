# %% [markdown]
# ## This Notebook - Goals - FOR EDINA
#
# **Aim:** <br>
# The purpose of this Notebook is to introduce the user to
#
# **Target audience:** <br>
# This Notebook is primarily aimed at users interested in geospatial data analysis.
#
# **Motivation:** <br>
# The motivation behind creating this exemplar is to promote Noteable by showing the large variety of libraries that are pre-installed in the Geospatial Notebook.
#
# **Noteable features to exploit:** <br>
# This Notebook focuses on one specific library included within the Geospatial Notebook
#
# **How are the features exploited:** <br>
#
# <hr>

# %%
import folium
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display
from folium import plugins
import bokeh

# %% [markdown]
# ## Folium maps

# %%
## Create the map using the OpenStreetMap tile
loc = [55.9533, -3.1883]
m = folium.Map(location=loc, tiles='OpenStreetMap', zoom_start=13)

tooltip = 'Click me!'
locationName = 'work'
workloc = [55.9465, -3.2007]
## Add a marker at your location
folium.Marker(workloc, popup=locationName).add_to(m)

## Add a red circle to the map
folium.Circle(
    radius=100,
    location=workloc,
    popup='The Waterfront',
    color='crimson',
    fill=False,
).add_to(m)

m.add_child(folium.LatLngPopup())

tooltip = 'Click me!'
locationName2 = 'home'
homeloc = [55.9399, -3.1773]
## Add a marker at your location
folium.Marker(homeloc, popup=locationName2).add_to(m)

folium.vector_layers.path_options(line=True, stroke=True)
path = [(55.9465, -3.2007), (55.9461, -3.2010), (55.9452, -3.1996), (55.9449, -3.1991), 
        (55.9449, -3.1952), (55.9453, -3.1912), (55.9426, -3.1914), (55.9423, -3.1904), 
        (55.9407, -3.1854), (55.9405, -3.1850), (55.9403, -3.1840), (55.9409, -3.1809), 
        (55.9399, -3.1802), (55.9405, -3.1780), (55.9399, -3.1773)]
plugins.AntPath(locations=path, smooth_factor=5).add_to(m)
plugins.Fullscreen(position='topleft', title='Full Screen', title_cancel='Exit Full Screen').add_to(m)
plugins.ScrollZoomToggler().add_to(m)

def tiles(tilemap):
    folium.raster_layers.TileLayer(tiles=tilemap, overlay=True).add_to(m)
    display(m)
tilemap=widgets.Dropdown(options=['OpenStreetMap', 'Stamen Terrain', 'Stamen Toner', 
                                  'Stamen Watercolor', 'CartoDB positron', 'CartoDB dark_matter'],
                         value='OpenStreetMap',
                         description='Choose base layer:',
                         continuous_update=True,
                         disabled=False,
                         style={'description_width': 'initial'})
# Create interative output
out = widgets.interactive_output(tiles, {'tilemap':tilemap})

# Display interactive widgets in UI
display(tilemap, out)
# Out:
# Dropdown(description='Choose base layer:', options=('OpenStreetMap', 'Stamen Terrain', 'Stamen Toner', 'Stamen…
# Output()

# %%
dataset = pd.read_csv('https://covid.ourworldindata.org/data/ecdc/full_data.csv')
dataset
# Out:
#              date     location  new_cases  new_deaths  total_cases  \
# 0      2019-12-31  Afghanistan        0.0         0.0          0.0
# 1      2020-01-01  Afghanistan        0.0         0.0          0.0
# 2      2020-01-02  Afghanistan        0.0         0.0          0.0
# 3      2020-01-03  Afghanistan        0.0         0.0          0.0
# 4      2020-01-04  Afghanistan        0.0         0.0          0.0
# ...           ...          ...        ...         ...          ...
# 31913  2020-07-18     Zimbabwe       58.0         1.0       1420.0
# 31914  2020-07-19     Zimbabwe       58.0         1.0       1478.0
# 31915  2020-07-20     Zimbabwe      133.0         0.0       1611.0
# 31916  2020-07-21     Zimbabwe      102.0         1.0       1713.0
# 31917  2020-07-22     Zimbabwe      107.0         0.0       1820.0
#
#        total_deaths  weekly_cases  weekly_deaths  biweekly_cases  \
# 0               0.0           NaN            NaN             NaN
# 1               0.0           NaN            NaN             NaN
# 2               0.0           NaN            NaN             NaN
# 3               0.0           NaN            NaN             NaN
# 4               0.0           NaN            NaN             NaN
# ...             ...           ...            ...             ...
# 31913          24.0         478.0           11.0           795.0
# 31914          25.0         496.0            7.0           780.0
# 31915          25.0         626.0            7.0           895.0
# 31916          26.0         679.0            7.0           979.0
# 31917          26.0         786.0            7.0          1033.0
#
#        biweekly_deaths
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 31913             17.0
# 31914             17.0
# 31915             17.0
# 31916             17.0
# 31917             17.0
#
# [31918 rows x 10 columns]

# %%
#We would use the requests module to pull the data from API
import requests
#Pulling the Worldwide COVID-19 data, we use the get function from requests module with API endpoint(Basically a URL address to request your data) as the function parameter. To know available endpoint, check the API documentation
res = requests.get('https://api.thevirustracker.com/free-api?countryTotals=ALL')
#We turn the data into json. It would become dictionary in the Python.
covid_current = res.json()
covid_current

#Creating the COVID-19 DataFrame
df = []
df2 = []
df3 = []
df4 = []
for j in range(1,len(covid_current['countryitems'][0])):
    df.append([covid_current['countryitems'][0]['{}'.format(j)]  ['title'],
         covid_current['countryitems'][0]['{}'.format(j)]['total_cases']])
    df_covid = pd.DataFrame(df, columns = ['Country', 'Total cases'])
    df2.append(covid_current['countryitems'][0]['{}'.format(j)]['total_serious_cases'])
    df_covid2 = pd.DataFrame(df2, columns = ['Total serious cases'])
    df3.append(covid_current['countryitems'][0]['{}'.format(j)]['total_recovered'])
    df_covid3 = pd.DataFrame(df3, columns = ['Total recovered'])
    df4.append(covid_current['countryitems'][0]['{}'.format(j)]['total_new_cases_today'])
    df_covid4 = pd.DataFrame(df4, columns = ['Total new cases today'])
    covid_all =pd.concat([df_covid, df_covid2, df_covid3, df_covid4], axis=1)

#Setting up the world countries data URL
url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
country_shapes = f'{url}/world-countries.json'

#Replacing the country namedf_covid.replace('USA', "United States of America", inplace = True)
covid_all.replace('Tanzania', "United Republic of Tanzania", inplace = True)
covid_all.replace('Democratic Republic of Congo', "Democratic Republic of the Congo", inplace = True)
covid_all.replace('Congo', "Republic of the Congo", inplace = True)
covid_all.replace('Lao', "Laos", inplace = True)
covid_all.replace('Syrian Arab Republic', "Syria", inplace = True)
covid_all.replace('Serbia', "Republic of Serbia", inplace = True)
covid_all.replace('Czechia', "Czech Republic", inplace = True)
covid_all.replace('UAE', "United Arab Emirates", inplace = True)

def layers(datacolumn):
    m = folium.Map()
    folium.Choropleth(geo_data=country_shapes, name='choropleth COVID-19',
                      data=covid_all, columns=['Country', datacolumn], 
                      key_on='feature.properties.name',
                      fill_color='PuRd', nan_fill_color='white').add_to(m)
    display(m)
datacolumn=widgets.Dropdown(options=['Total cases', 'Total serious cases', 'Total recovered', 'Total new cases today'],
                         value='Total cases',
                         description='Choose which data layer to show:',
                         continuous_update=True,
                         disabled=False,
                         style={'description_width': 'initial'})
# Create interative output
out = widgets.interactive_output(layers, {'datacolumn':datacolumn})

# Display interactive widgets in UI
display(datacolumn, out)
# Out:
# Dropdown(description='Choose which data layer to show:', options=('Total cases', 'Total serious cases', 'Total…
# Output()

# %%
covid_current
# Out:
# {'countryitems': [{'1': {'code': 'AF',
#     'ourid': 1,
#     'source': 'https://thevirustracker.com/afghanistan-coronavirus-information-af',
#     'title': 'Afghanistan',
#     'total_active_cases': 614,
#     'total_cases': 35915,
#     'total_deaths': 1211,
#     'total_new_cases_today': 188,
#     'total_new_deaths_today': 21,
#     'total_recovered': 24538,
#     'total_serious_cases': 10166,
#     'total_unresolved': 0},
#    '10': {'code': 'BS',
#     'ourid': 10,
#     'source': 'https://thevirustracker.com/bahamas-coronavirus-information-bs',
#     'title': 'Bahamas',
#     'total_active_cases': 0,
#     'total_cases': 219,
#     'total_deaths': 11,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 91,
#     'total_serious_cases': 117,
#     'total_unresolved': 0},
#    '100': {'code': 'MR',
#     'ourid': 101,
#     'source': 'https://thevirustracker.com/mauritania-coronavirus-information-mr',
#     'title': 'Mauritania',
#     'total_active_cases': 0,
#     'total_cases': 6027,
#     'total_deaths': 155,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 3977,
#     'total_serious_cases': 1895,
#     'total_unresolved': 0},
#    '101': {'code': 'MX',
#     'ourid': 102,
#     'source': 'https://thevirustracker.com/mexico-coronavirus-information-mx',
#     'title': 'Mexico',
#     'total_active_cases': 4238,
#     'total_cases': 362274,
#     'total_deaths': 41190,
#     'total_new_cases_today': 6019,
#     'total_new_deaths_today': 790,
#     'total_recovered': 231403,
#     'total_serious_cases': 89681,
#     'total_unresolved': 0},
#    '102': {'code': 'MD',
#     'ourid': 103,
#     'source': 'https://thevirustracker.com/moldova-coronavirus-information-md',
#     'title': 'Moldova',
#     'total_active_cases': 1318,
#     'total_cases': 21798,
#     'total_deaths': 713,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 1,
#     'total_recovered': 16174,
#     'total_serious_cases': 4911,
#     'total_unresolved': 0},
#    '103': {'code': 'MN',
#     'ourid': 104,
#     'source': 'https://thevirustracker.com/mongolia-coronavirus-information-mn',
#     'title': 'Mongolia',
#     'total_active_cases': 1,
#     'total_cases': 287,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 214,
#     'total_serious_cases': 73,
#     'total_unresolved': 0},
#    '104': {'code': 'ME',
#     'ourid': 105,
#     'source': 'https://thevirustracker.com/montenegro-coronavirus-information-me',
#     'title': 'Montenegro',
#     'total_active_cases': 0,
#     'total_cases': 2472,
#     'total_deaths': 39,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 496,
#     'total_serious_cases': 1937,
#     'total_unresolved': 0},
#    '105': {'code': 'MA',
#     'ourid': 106,
#     'source': 'https://thevirustracker.com/morocco-coronavirus-information-ma',
#     'title': 'Morocco',
#     'total_active_cases': 0,
#     'total_cases': 17962,
#     'total_deaths': 285,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 15636,
#     'total_serious_cases': 2041,
#     'total_unresolved': 0},
#    '106': {'code': 'MZ',
#     'ourid': 107,
#     'source': 'https://thevirustracker.com/mozambique-coronavirus-information-mz',
#     'title': 'Mozambique',
#     'total_active_cases': 0,
#     'total_cases': 1557,
#     'total_deaths': 11,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 523,
#     'total_serious_cases': 1023,
#     'total_unresolved': 0},
#    '107': {'code': 'MM',
#     'ourid': 108,
#     'source': 'https://thevirustracker.com/myanmar-coronavirus-information-mm',
#     'title': 'Myanmar',
#     'total_active_cases': 0,
#     'total_cases': 343,
#     'total_deaths': 6,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 280,
#     'total_serious_cases': 57,
#     'total_unresolved': 0},
#    '108': {'code': 'NA',
#     'ourid': 109,
#     'source': 'https://thevirustracker.com/namibia-coronavirus-information-na',
#     'title': 'Namibia',
#     'total_active_cases': 0,
#     'total_cases': 1402,
#     'total_deaths': 7,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 64,
#     'total_serious_cases': 1331,
#     'total_unresolved': 0},
#    '109': {'code': 'NP',
#     'ourid': 110,
#     'source': 'https://thevirustracker.com/nepal-coronavirus-information-np',
#     'title': 'Nepal',
#     'total_active_cases': 0,
#     'total_cases': 18094,
#     'total_deaths': 42,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 12684,
#     'total_serious_cases': 5368,
#     'total_unresolved': 0},
#    '11': {'code': 'BD',
#     'ourid': 11,
#     'source': 'https://thevirustracker.com/bangladesh-coronavirus-information-bd',
#     'title': 'Bangladesh',
#     'total_active_cases': 0,
#     'total_cases': 213254,
#     'total_deaths': 2751,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 117202,
#     'total_serious_cases': 93301,
#     'total_unresolved': 0},
#    '110': {'code': 'NL',
#     'ourid': 111,
#     'source': 'https://thevirustracker.com/netherlands-coronavirus-information-nl',
#     'title': 'Netherlands',
#     'total_active_cases': 0,
#     'total_cases': 52242,
#     'total_deaths': 6139,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '111': {'code': 'NC',
#     'ourid': 112,
#     'source': 'https://thevirustracker.com/new-caledonia-coronavirus-information-nc',
#     'title': 'New Caledonia',
#     'total_active_cases': 0,
#     'total_cases': 22,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 21,
#     'total_serious_cases': 1,
#     'total_unresolved': 0},
#    '112': {'code': 'NZ',
#     'ourid': 113,
#     'source': 'https://thevirustracker.com/new-zealand-coronavirus-information-nz',
#     'title': 'New Zealand',
#     'total_active_cases': 0,
#     'total_cases': 1555,
#     'total_deaths': 22,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1511,
#     'total_serious_cases': 22,
#     'total_unresolved': 0},
#    '113': {'code': 'NI',
#     'ourid': 114,
#     'source': 'https://thevirustracker.com/nicaragua-coronavirus-information-ni',
#     'title': 'Nicaragua',
#     'total_active_cases': 0,
#     'total_cases': 3439,
#     'total_deaths': 108,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 2492,
#     'total_serious_cases': 839,
#     'total_unresolved': 0},
#    '114': {'code': 'NE',
#     'ourid': 115,
#     'source': 'https://thevirustracker.com/niger-coronavirus-information-ne',
#     'title': 'Niger',
#     'total_active_cases': 0,
#     'total_cases': 1122,
#     'total_deaths': 69,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1018,
#     'total_serious_cases': 35,
#     'total_unresolved': 0},
#    '115': {'code': 'NG',
#     'ourid': 116,
#     'source': 'https://thevirustracker.com/nigeria-coronavirus-information-ng',
#     'title': 'Nigeria',
#     'total_active_cases': 0,
#     'total_cases': 38344,
#     'total_deaths': 813,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 15815,
#     'total_serious_cases': 21716,
#     'total_unresolved': 0},
#    '116': {'code': 'NO',
#     'ourid': 117,
#     'source': 'https://thevirustracker.com/norway-coronavirus-information-no',
#     'title': 'Norway',
#     'total_active_cases': 0,
#     'total_cases': 9059,
#     'total_deaths': 255,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 8138,
#     'total_serious_cases': 666,
#     'total_unresolved': 0},
#    '117': {'code': 'OM',
#     'ourid': 118,
#     'source': 'https://thevirustracker.com/oman-coronavirus-information-om',
#     'title': 'Oman',
#     'total_active_cases': 0,
#     'total_cases': 71547,
#     'total_deaths': 349,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 47922,
#     'total_serious_cases': 23276,
#     'total_unresolved': 0},
#    '118': {'code': 'PK',
#     'ourid': 119,
#     'source': 'https://thevirustracker.com/pakistan-coronavirus-information-pk',
#     'title': 'Pakistan',
#     'total_active_cases': 2707,
#     'total_cases': 269191,
#     'total_deaths': 5709,
#     'total_new_cases_today': 1763,
#     'total_new_deaths_today': 32,
#     'total_recovered': 213175,
#     'total_serious_cases': 50307,
#     'total_unresolved': 0},
#    '119': {'code': 'PS',
#     'ourid': 120,
#     'source': 'https://thevirustracker.com/palestine-coronavirus-information-ps',
#     'title': 'Palestine',
#     'total_active_cases': 0,
#     'total_cases': 9398,
#     'total_deaths': 66,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1950,
#     'total_serious_cases': 7382,
#     'total_unresolved': 0},
#    '12': {'code': 'BY',
#     'ourid': 12,
#     'source': 'https://thevirustracker.com/belarus-coronavirus-information-by',
#     'title': 'Belarus',
#     'total_active_cases': 0,
#     'total_cases': 66521,
#     'total_deaths': 513,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 59061,
#     'total_serious_cases': 6947,
#     'total_unresolved': 0},
#    '120': {'code': 'PA',
#     'ourid': 121,
#     'source': 'https://thevirustracker.com/panama-coronavirus-information-pa',
#     'title': 'Panama',
#     'total_active_cases': 0,
#     'total_cases': 55906,
#     'total_deaths': 1180,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 31122,
#     'total_serious_cases': 23604,
#     'total_unresolved': 0},
#    '121': {'code': 'PG',
#     'ourid': 122,
#     'source': 'https://thevirustracker.com/papua-new-guinea-coronavirus-information-pg',
#     'title': 'Papua New Guinea',
#     'total_active_cases': 0,
#     'total_cases': 30,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 8,
#     'total_serious_cases': 22,
#     'total_unresolved': 0},
#    '122': {'code': 'PY',
#     'ourid': 123,
#     'source': 'https://thevirustracker.com/paraguay-coronavirus-information-py',
#     'title': 'Paraguay',
#     'total_active_cases': 0,
#     'total_cases': 4000,
#     'total_deaths': 36,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 2391,
#     'total_serious_cases': 1573,
#     'total_unresolved': 0},
#    '123': {'code': 'PE',
#     'ourid': 124,
#     'source': 'https://thevirustracker.com/peru-coronavirus-information-pe',
#     'title': 'Peru',
#     'total_active_cases': 0,
#     'total_cases': 366550,
#     'total_deaths': 17455,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 252246,
#     'total_serious_cases': 96849,
#     'total_unresolved': 0},
#    '124': {'code': 'PH',
#     'ourid': 125,
#     'source': 'https://thevirustracker.com/philippines-coronavirus-information-ph',
#     'title': 'Philippines',
#     'total_active_cases': 0,
#     'total_cases': 72269,
#     'total_deaths': 1843,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 23623,
#     'total_serious_cases': 46803,
#     'total_unresolved': 0},
#    '125': {'code': 'PL',
#     'ourid': 126,
#     'source': 'https://thevirustracker.com/poland-coronavirus-information-pl',
#     'title': 'Poland',
#     'total_active_cases': 402,
#     'total_cases': 41162,
#     'total_deaths': 1642,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 31541,
#     'total_serious_cases': 7979,
#     'total_unresolved': 0},
#    '126': {'code': 'PT',
#     'ourid': 127,
#     'source': 'https://thevirustracker.com/portugal-coronavirus-information-pt',
#     'title': 'Portugal',
#     'total_active_cases': 0,
#     'total_cases': 49150,
#     'total_deaths': 1702,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 33999,
#     'total_serious_cases': 13449,
#     'total_unresolved': 0},
#    '127': {'code': 'PR',
#     'ourid': 128,
#     'source': 'https://thevirustracker.com/puerto-rico-coronavirus-information-pr',
#     'title': 'Puerto Rico',
#     'total_active_cases': 36,
#     'total_cases': 39,
#     'total_deaths': 2,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '128': {'code': 'QA',
#     'ourid': 129,
#     'source': 'https://thevirustracker.com/qatar-coronavirus-information-qa',
#     'title': 'Qatar',
#     'total_active_cases': 0,
#     'total_cases': 107871,
#     'total_deaths': 163,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 104641,
#     'total_serious_cases': 3067,
#     'total_unresolved': 0},
#    '129': {'code': 'XK',
#     'ourid': 130,
#     'source': 'https://thevirustracker.com/republic-of-kosovo-coronavirus-information-xk',
#     'title': 'Republic of Kosovo',
#     'total_active_cases': 0,
#     'total_cases': 0,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '13': {'code': 'BE',
#     'ourid': 13,
#     'source': 'https://thevirustracker.com/belgium-coronavirus-information-be',
#     'title': 'Belgium',
#     'total_active_cases': 17,
#     'total_cases': 64627,
#     'total_deaths': 9808,
#     'total_new_cases_today': 369,
#     'total_new_deaths_today': 3,
#     'total_recovered': 17347,
#     'total_serious_cases': 37472,
#     'total_unresolved': 0},
#    '130': {'code': 'RO',
#     'ourid': 131,
#     'source': 'https://thevirustracker.com/romania-coronavirus-information-ro',
#     'title': 'Romania',
#     'total_active_cases': 0,
#     'total_cases': 40163,
#     'total_deaths': 2101,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 24663,
#     'total_serious_cases': 13399,
#     'total_unresolved': 0},
#    '131': {'code': 'RW',
#     'ourid': 133,
#     'source': 'https://thevirustracker.com/rwanda-coronavirus-information-rw',
#     'title': 'Rwanda',
#     'total_active_cases': 0,
#     'total_cases': 1689,
#     'total_deaths': 5,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 867,
#     'total_serious_cases': 817,
#     'total_unresolved': 0},
#    '132': {'code': 'SA',
#     'ourid': 134,
#     'source': 'https://thevirustracker.com/saudi-arabia-coronavirus-information-sa',
#     'title': 'Saudi Arabia',
#     'total_active_cases': 0,
#     'total_cases': 258156,
#     'total_deaths': 2601,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 210398,
#     'total_serious_cases': 45157,
#     'total_unresolved': 0},
#    '133': {'code': 'SN',
#     'ourid': 135,
#     'source': 'https://thevirustracker.com/senegal-coronavirus-information-sn',
#     'title': 'Senegal',
#     'total_active_cases': 0,
#     'total_cases': 9121,
#     'total_deaths': 177,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 6108,
#     'total_serious_cases': 2836,
#     'total_unresolved': 0},
#    '134': {'code': 'RS',
#     'ourid': 136,
#     'source': 'https://thevirustracker.com/serbia-coronavirus-information-rs',
#     'title': 'Serbia',
#     'total_active_cases': 0,
#     'total_cases': 22031,
#     'total_deaths': 499,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 14047,
#     'total_serious_cases': 7485,
#     'total_unresolved': 0},
#    '135': {'code': 'SL',
#     'ourid': 137,
#     'source': 'https://thevirustracker.com/sierra-leone-coronavirus-information-sl',
#     'title': 'Sierra Leone',
#     'total_active_cases': 0,
#     'total_cases': 1731,
#     'total_deaths': 66,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1288,
#     'total_serious_cases': 377,
#     'total_unresolved': 0},
#    '136': {'code': 'SK',
#     'ourid': 138,
#     'source': 'https://thevirustracker.com/slovakia-coronavirus-information-sk',
#     'title': 'Slovakia',
#     'total_active_cases': 0,
#     'total_cases': 2058,
#     'total_deaths': 28,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1556,
#     'total_serious_cases': 474,
#     'total_unresolved': 0},
#    '137': {'code': 'SI',
#     'ourid': 139,
#     'source': 'https://thevirustracker.com/slovenia-coronavirus-information-si',
#     'title': 'Slovenia',
#     'total_active_cases': 0,
#     'total_cases': 2006,
#     'total_deaths': 115,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1648,
#     'total_serious_cases': 243,
#     'total_unresolved': 0},
#    '138': {'code': 'SB',
#     'ourid': 140,
#     'source': 'https://thevirustracker.com/solomon-islands-coronavirus-information-sb',
#     'title': 'Solomon Islands',
#     'total_active_cases': 0,
#     'total_cases': 0,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '139': {'code': 'SO',
#     'ourid': 141,
#     'source': 'https://thevirustracker.com/somalia-coronavirus-information-so',
#     'title': 'Somalia',
#     'total_active_cases': 0,
#     'total_cases': 3161,
#     'total_deaths': 93,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1495,
#     'total_serious_cases': 1573,
#     'total_unresolved': 0},
#    '14': {'code': 'BZ',
#     'ourid': 14,
#     'source': 'https://thevirustracker.com/belize-coronavirus-information-bz',
#     'title': 'Belize',
#     'total_active_cases': 0,
#     'total_cases': 43,
#     'total_deaths': 2,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 23,
#     'total_serious_cases': 18,
#     'total_unresolved': 0},
#    '140': {'code': 'ZA',
#     'ourid': 142,
#     'source': 'https://thevirustracker.com/south-africa-coronavirus-information-za',
#     'title': 'South Africa',
#     'total_active_cases': 0,
#     'total_cases': 394948,
#     'total_deaths': 5940,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 229175,
#     'total_serious_cases': 159833,
#     'total_unresolved': 0},
#    '141': {'code': 'SS',
#     'ourid': 143,
#     'source': 'https://thevirustracker.com/south-sudan-coronavirus-information-ss',
#     'title': 'South Sudan',
#     'total_active_cases': 0,
#     'total_cases': 2211,
#     'total_deaths': 45,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1175,
#     'total_serious_cases': 991,
#     'total_unresolved': 0},
#    '142': {'code': 'ES',
#     'ourid': 144,
#     'source': 'https://thevirustracker.com/spain-coronavirus-information-es',
#     'title': 'Spain',
#     'total_active_cases': 0,
#     'total_cases': 314631,
#     'total_deaths': 28426,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '143': {'code': 'LK',
#     'ourid': 145,
#     'source': 'https://thevirustracker.com/sri-lanka-coronavirus-information-lk',
#     'title': 'Sri Lanka',
#     'total_active_cases': 13,
#     'total_cases': 2752,
#     'total_deaths': 11,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 2077,
#     'total_serious_cases': 664,
#     'total_unresolved': 0},
#    '144': {'code': 'SD',
#     'ourid': 146,
#     'source': 'https://thevirustracker.com/sudan-coronavirus-information-sd',
#     'title': 'Sudan',
#     'total_active_cases': 0,
#     'total_cases': 11237,
#     'total_deaths': 708,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 5835,
#     'total_serious_cases': 4694,
#     'total_unresolved': 0},
#    '145': {'code': 'SR',
#     'ourid': 147,
#     'source': 'https://thevirustracker.com/suriname-coronavirus-information-sr',
#     'title': 'Suriname',
#     'total_active_cases': 0,
#     'total_cases': 1176,
#     'total_deaths': 21,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 739,
#     'total_serious_cases': 416,
#     'total_unresolved': 0},
#    '146': {'code': 'SJ',
#     'ourid': 148,
#     'source': 'https://thevirustracker.com/svalbard-and-jan-mayen-coronavirus-information-sj',
#     'title': 'Svalbard and Jan Mayen',
#     'total_active_cases': 0,
#     'total_cases': 0,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '147': {'code': 'SZ',
#     'ourid': 149,
#     'source': 'https://thevirustracker.com/swaziland-coronavirus-information-sz',
#     'title': 'Swaziland',
#     'total_active_cases': 0,
#     'total_cases': 0,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '148': {'code': 'SE',
#     'ourid': 150,
#     'source': 'https://thevirustracker.com/sweden-coronavirus-information-se',
#     'title': 'Sweden',
#     'total_active_cases': 0,
#     'total_cases': 78504,
#     'total_deaths': 5667,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '149': {'code': 'CH',
#     'ourid': 151,
#     'source': 'https://thevirustracker.com/switzerland-coronavirus-information-ch',
#     'title': 'Switzerland',
#     'total_active_cases': 0,
#     'total_cases': 33883,
#     'total_deaths': 1972,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 30500,
#     'total_serious_cases': 1411,
#     'total_unresolved': 0},
#    '15': {'code': 'BJ',
#     'ourid': 15,
#     'source': 'https://thevirustracker.com/benin-coronavirus-information-bj',
#     'title': 'Benin',
#     'total_active_cases': 0,
#     'total_cases': 1690,
#     'total_deaths': 34,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 782,
#     'total_serious_cases': 874,
#     'total_unresolved': 0},
#    '150': {'code': 'SY',
#     'ourid': 152,
#     'source': 'https://thevirustracker.com/syrian-arab-republic-coronavirus-information-sy',
#     'title': 'Syrian Arab Republic',
#     'total_active_cases': 0,
#     'total_cases': 0,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '151': {'code': 'TW',
#     'ourid': 153,
#     'source': 'https://thevirustracker.com/taiwan-coronavirus-information-tw',
#     'title': 'Taiwan',
#     'total_active_cases': 0,
#     'total_cases': 455,
#     'total_deaths': 7,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 440,
#     'total_serious_cases': 8,
#     'total_unresolved': 0},
#    '152': {'code': 'TJ',
#     'ourid': 154,
#     'source': 'https://thevirustracker.com/tajikistan-coronavirus-information-tj',
#     'title': 'Tajikistan',
#     'total_active_cases': 0,
#     'total_cases': 7015,
#     'total_deaths': 58,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 5741,
#     'total_serious_cases': 1216,
#     'total_unresolved': 0},
#    '153': {'code': 'TZ',
#     'ourid': 155,
#     'source': 'https://thevirustracker.com/tanzania-coronavirus-information-tz',
#     'title': 'Tanzania',
#     'total_active_cases': 0,
#     'total_cases': 509,
#     'total_deaths': 21,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 183,
#     'total_serious_cases': 305,
#     'total_unresolved': 0},
#    '154': {'code': 'TH',
#     'ourid': 156,
#     'source': 'https://thevirustracker.com/thailand-coronavirus-information-th',
#     'title': 'Thailand',
#     'total_active_cases': 0,
#     'total_cases': 3269,
#     'total_deaths': 58,
#     'total_new_cases_today': 8,
#     'total_new_deaths_today': 0,
#     'total_recovered': 3105,
#     'total_serious_cases': 106,
#     'total_unresolved': 0},
#    '155': {'code': 'TL',
#     'ourid': 157,
#     'source': 'https://thevirustracker.com/timor-leste-coronavirus-information-tl',
#     'title': 'Timor-Leste',
#     'total_active_cases': 21,
#     'total_cases': 0,
#     'total_deaths': 0,
#     'total_new_cases_today': 24,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 3,
#     'total_unresolved': 0},
#    '156': {'code': 'TG',
#     'ourid': 158,
#     'source': 'https://thevirustracker.com/togo-coronavirus-information-tg',
#     'title': 'Togo',
#     'total_active_cases': 0,
#     'total_cases': 806,
#     'total_deaths': 16,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 578,
#     'total_serious_cases': 212,
#     'total_unresolved': 0},
#    '157': {'code': 'TT',
#     'ourid': 159,
#     'source': 'https://thevirustracker.com/trinidad-and-tobago-coronavirus-information-tt',
#     'title': 'Trinidad and Tobago',
#     'total_active_cases': 0,
#     'total_cases': 141,
#     'total_deaths': 8,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 127,
#     'total_serious_cases': 6,
#     'total_unresolved': 0},
#    '158': {'code': 'TN',
#     'ourid': 160,
#     'source': 'https://thevirustracker.com/tunisia-coronavirus-information-tn',
#     'title': 'Tunisia',
#     'total_active_cases': 0,
#     'total_cases': 1394,
#     'total_deaths': 50,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1108,
#     'total_serious_cases': 236,
#     'total_unresolved': 0},
#    '159': {'code': 'TR',
#     'ourid': 161,
#     'source': 'https://thevirustracker.com/turkey-coronavirus-information-tr',
#     'title': 'Turkey',
#     'total_active_cases': 0,
#     'total_cases': 222402,
#     'total_deaths': 5545,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 205214,
#     'total_serious_cases': 11643,
#     'total_unresolved': 0},
#    '16': {'code': 'BT',
#     'ourid': 16,
#     'source': 'https://thevirustracker.com/bhutan-coronavirus-information-bt',
#     'title': 'Bhutan',
#     'total_active_cases': 0,
#     'total_cases': 92,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 83,
#     'total_serious_cases': 9,
#     'total_unresolved': 0},
#    '160': {'code': 'TM',
#     'ourid': 162,
#     'source': 'https://thevirustracker.com/turkmenistan-coronavirus-information-tm',
#     'title': 'Turkmenistan',
#     'total_active_cases': 0,
#     'total_cases': 0,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '161': {'code': 'UG',
#     'ourid': 163,
#     'source': 'https://thevirustracker.com/uganda-coronavirus-information-ug',
#     'title': 'Uganda',
#     'total_active_cases': 0,
#     'total_cases': 1075,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 958,
#     'total_serious_cases': 117,
#     'total_unresolved': 0},
#    '162': {'code': 'UA',
#     'ourid': 164,
#     'source': 'https://thevirustracker.com/ukraine-coronavirus-information-ua',
#     'title': 'Ukraine',
#     'total_active_cases': 828,
#     'total_cases': 61851,
#     'total_deaths': 1551,
#     'total_new_cases_today': 856,
#     'total_new_deaths_today': 17,
#     'total_recovered': 34000,
#     'total_serious_cases': 26300,
#     'total_unresolved': 0},
#    '163': {'code': 'GB',
#     'ourid': 166,
#     'source': 'https://thevirustracker.com/united-kingdom-coronavirus-information-gb',
#     'title': 'United Kingdom',
#     'total_active_cases': 0,
#     'total_cases': 296377,
#     'total_deaths': 45501,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '164': {'code': 'US',
#     'ourid': 167,
#     'source': 'https://thevirustracker.com/usa-coronavirus-information-us',
#     'title': 'USA',
#     'total_active_cases': 178,
#     'total_cases': 4101000,
#     'total_deaths': 146185,
#     'total_new_cases_today': 125,
#     'total_new_deaths_today': 2,
#     'total_recovered': 1942815,
#     'total_serious_cases': 2012000,
#     'total_unresolved': 0},
#    '165': {'code': 'UY',
#     'ourid': 168,
#     'source': 'https://thevirustracker.com/uruguay-coronavirus-information-uy',
#     'title': 'Uruguay',
#     'total_active_cases': 0,
#     'total_cases': 1117,
#     'total_deaths': 34,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 934,
#     'total_serious_cases': 149,
#     'total_unresolved': 0},
#    '166': {'code': 'UZ',
#     'ourid': 169,
#     'source': 'https://thevirustracker.com/uzbekistan-coronavirus-information-uz',
#     'title': 'Uzbekistan',
#     'total_active_cases': 0,
#     'total_cases': 18531,
#     'total_deaths': 99,
#     'total_new_cases_today': 152,
#     'total_new_deaths_today': 1,
#     'total_recovered': 9872,
#     'total_serious_cases': 8560,
#     'total_unresolved': 0},
#    '167': {'code': 'VU',
#     'ourid': 170,
#     'source': 'https://thevirustracker.com/vanuatu-coronavirus-information-vu',
#     'title': 'Vanuatu',
#     'total_active_cases': 0,
#     'total_cases': 0,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '168': {'code': 'VE',
#     'ourid': 171,
#     'source': 'https://thevirustracker.com/venezuela-coronavirus-information-ve',
#     'title': 'Venezuela',
#     'total_active_cases': 0,
#     'total_cases': 13164,
#     'total_deaths': 124,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 7471,
#     'total_serious_cases': 5569,
#     'total_unresolved': 0},
#    '169': {'code': 'EH',
#     'ourid': 173,
#     'source': 'https://thevirustracker.com/western-sahara-coronavirus-information-eh',
#     'title': 'Western Sahara',
#     'total_active_cases': 0,
#     'total_cases': 10,
#     'total_deaths': 1,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 8,
#     'total_serious_cases': 1,
#     'total_unresolved': 0},
#    '17': {'code': 'BO',
#     'ourid': 17,
#     'source': 'https://thevirustracker.com/bolivia-coronavirus-information-bo',
#     'title': 'Bolivia',
#     'total_active_cases': 431,
#     'total_cases': 64135,
#     'total_deaths': 2328,
#     'total_new_cases_today': 1778,
#     'total_new_deaths_today': 55,
#     'total_recovered': 19721,
#     'total_serious_cases': 42086,
#     'total_unresolved': 0},
#    '170': {'code': 'YE',
#     'ourid': 174,
#     'source': 'https://thevirustracker.com/yemen-coronavirus-information-ye',
#     'title': 'Yemen',
#     'total_active_cases': 0,
#     'total_cases': 1640,
#     'total_deaths': 458,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 751,
#     'total_serious_cases': 431,
#     'total_unresolved': 0},
#    '171': {'code': 'ZM',
#     'ourid': 175,
#     'source': 'https://thevirustracker.com/zambia-coronavirus-information-zm',
#     'title': 'Zambia',
#     'total_active_cases': 0,
#     'total_cases': 3583,
#     'total_deaths': 128,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1677,
#     'total_serious_cases': 1778,
#     'total_unresolved': 0},
#    '172': {'code': 'ZW',
#     'ourid': 176,
#     'source': 'https://thevirustracker.com/zimbabwe-coronavirus-information-zw',
#     'title': 'Zimbabwe',
#     'total_active_cases': 0,
#     'total_cases': 2034,
#     'total_deaths': 26,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 510,
#     'total_serious_cases': 1498,
#     'total_unresolved': 0},
#    '173': {'code': 'SG',
#     'ourid': 177,
#     'source': 'https://thevirustracker.com/singapore-coronavirus-information-sg',
#     'title': 'Singapore',
#     'total_active_cases': 0,
#     'total_cases': 49098,
#     'total_deaths': 27,
#     'total_new_cases_today': 354,
#     'total_new_deaths_today': 0,
#     'total_recovered': 44795,
#     'total_serious_cases': 4276,
#     'total_unresolved': 0},
#    '174': {'code': 'HK',
#     'ourid': 178,
#     'source': 'https://thevirustracker.com/hong-kong-coronavirus-information-hk',
#     'title': 'Hong Kong',
#     'total_active_cases': 0,
#     'total_cases': 2132,
#     'total_deaths': 14,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1344,
#     'total_serious_cases': 774,
#     'total_unresolved': 0},
#    '175': {'code': 'CD',
#     'ourid': 195,
#     'source': 'https://thevirustracker.com/dr-congo-coronavirus-information-cd',
#     'title': 'DR Congo',
#     'total_active_cases': 0,
#     'total_cases': 0,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '176': {'code': 'XK',
#     'ourid': 196,
#     'source': 'https://thevirustracker.com/kosovo-coronavirus-information-xk',
#     'title': 'Kosovo',
#     'total_active_cases': 0,
#     'total_cases': 0,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '177': {'code': 'DP',
#     'ourid': 179,
#     'source': 'https://thevirustracker.com/diamond-princess-coronavirus-information-dp',
#     'title': 'Diamond Princess',
#     'total_active_cases': 0,
#     'total_cases': 712,
#     'total_deaths': 13,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 651,
#     'total_serious_cases': 48,
#     'total_unresolved': 0},
#    '178': {'code': 'IR',
#     'ourid': 180,
#     'source': 'https://thevirustracker.com/iran-coronavirus-information-ir',
#     'title': 'Iran',
#     'total_active_cases': 0,
#     'total_cases': 281413,
#     'total_deaths': 14853,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 244840,
#     'total_serious_cases': 21720,
#     'total_unresolved': 0},
#    '179': {'code': 'KP',
#     'ourid': 186,
#     'source': 'https://thevirustracker.com/north-korea-coronavirus-information-kp',
#     'title': 'North Korea',
#     'total_active_cases': 0,
#     'total_cases': 0,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '18': {'code': 'BA',
#     'ourid': 18,
#     'source': 'https://thevirustracker.com/bosnia-and-herzegovina-coronavirus-information-ba',
#     'title': 'Bosnia and Herzegovina',
#     'total_active_cases': 0,
#     'total_cases': 9115,
#     'total_deaths': 268,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 4159,
#     'total_serious_cases': 4688,
#     'total_unresolved': 0},
#    '180': {'code': 'RU',
#     'ourid': 191,
#     'source': 'https://thevirustracker.com/russia-coronavirus-information-ru',
#     'title': 'Russia',
#     'total_active_cases': 8277,
#     'total_cases': 795038,
#     'total_deaths': 12892,
#     'total_new_cases_today': 5848,
#     'total_new_deaths_today': 147,
#     'total_recovered': 580330,
#     'total_serious_cases': 201816,
#     'total_unresolved': 0},
#    '181': {'code': 'AE',
#     'ourid': 192,
#     'source': 'https://thevirustracker.com/uae-coronavirus-information-ae',
#     'title': 'UAE',
#     'total_active_cases': 0,
#     'total_cases': 57734,
#     'total_deaths': 342,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 50354,
#     'total_serious_cases': 7038,
#     'total_unresolved': 0},
#    '182': {'code': 'VN',
#     'ourid': 193,
#     'source': 'https://thevirustracker.com/vietnam-coronavirus-information-vn',
#     'title': 'Vietnam',
#     'total_active_cases': 0,
#     'total_cases': 408,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 365,
#     'total_serious_cases': 43,
#     'total_unresolved': 0},
#    '19': {'code': 'BW',
#     'ourid': 19,
#     'source': 'https://thevirustracker.com/botswana-coronavirus-information-bw',
#     'title': 'Botswana',
#     'total_active_cases': 0,
#     'total_cases': 522,
#     'total_deaths': 1,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 48,
#     'total_serious_cases': 473,
#     'total_unresolved': 0},
#    '2': {'code': 'AL',
#     'ourid': 2,
#     'source': 'https://thevirustracker.com/albania-coronavirus-information-al',
#     'title': 'Albania',
#     'total_active_cases': 0,
#     'total_cases': 4358,
#     'total_deaths': 120,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 2463,
#     'total_serious_cases': 1775,
#     'total_unresolved': 0},
#    '20': {'code': 'BR',
#     'ourid': 20,
#     'source': 'https://thevirustracker.com/brazil-coronavirus-information-br',
#     'title': 'Brazil',
#     'total_active_cases': 0,
#     'total_cases': 2231871,
#     'total_deaths': 82890,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1532138,
#     'total_serious_cases': 616843,
#     'total_unresolved': 0},
#    '21': {'code': 'BN',
#     'ourid': 21,
#     'source': 'https://thevirustracker.com/brunei-darussalam-coronavirus-information-bn',
#     'title': 'Brunei Darussalam',
#     'total_active_cases': 0,
#     'total_cases': 141,
#     'total_deaths': 2,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 138,
#     'total_serious_cases': 1,
#     'total_unresolved': 0},
#    '22': {'code': 'BG',
#     'ourid': 22,
#     'source': 'https://thevirustracker.com/bulgaria-coronavirus-information-bg',
#     'title': 'Bulgaria',
#     'total_active_cases': 0,
#     'total_cases': 9584,
#     'total_deaths': 321,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 4643,
#     'total_serious_cases': 4620,
#     'total_unresolved': 0},
#    '23': {'code': 'BF',
#     'ourid': 23,
#     'source': 'https://thevirustracker.com/burkina-faso-coronavirus-information-bf',
#     'title': 'Burkina Faso',
#     'total_active_cases': 0,
#     'total_cases': 1066,
#     'total_deaths': 53,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 917,
#     'total_serious_cases': 96,
#     'total_unresolved': 0},
#    '24': {'code': 'BI',
#     'ourid': 24,
#     'source': 'https://thevirustracker.com/burundi-coronavirus-information-bi',
#     'title': 'Burundi',
#     'total_active_cases': 0,
#     'total_cases': 328,
#     'total_deaths': 1,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 207,
#     'total_serious_cases': 120,
#     'total_unresolved': 0},
#    '25': {'code': 'KH',
#     'ourid': 25,
#     'source': 'https://thevirustracker.com/cambodia-coronavirus-information-kh',
#     'title': 'Cambodia',
#     'total_active_cases': 2,
#     'total_cases': 198,
#     'total_deaths': 0,
#     'total_new_cases_today': 1,
#     'total_new_deaths_today': 0,
#     'total_recovered': 142,
#     'total_serious_cases': 56,
#     'total_unresolved': 0},
#    '26': {'code': 'CM',
#     'ourid': 26,
#     'source': 'https://thevirustracker.com/cameroon-coronavirus-information-cm',
#     'title': 'Cameroon',
#     'total_active_cases': 0,
#     'total_cases': 16522,
#     'total_deaths': 382,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 13728,
#     'total_serious_cases': 2412,
#     'total_unresolved': 0},
#    '27': {'code': 'CA',
#     'ourid': 27,
#     'source': 'https://thevirustracker.com/canada-coronavirus-information-ca',
#     'title': 'Canada',
#     'total_active_cases': 0,
#     'total_cases': 112240,
#     'total_deaths': 8870,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 98142,
#     'total_serious_cases': 5228,
#     'total_unresolved': 0},
#    '28': {'code': 'CF',
#     'ourid': 28,
#     'source': 'https://thevirustracker.com/central-african-republic-coronavirus-information-cf',
#     'title': 'Central African Republic',
#     'total_active_cases': 0,
#     'total_cases': 1,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '29': {'code': 'TD',
#     'ourid': 29,
#     'source': 'https://thevirustracker.com/chad-coronavirus-information-td',
#     'title': 'Chad',
#     'total_active_cases': 0,
#     'total_cases': 889,
#     'total_deaths': 75,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 805,
#     'total_serious_cases': 9,
#     'total_unresolved': 0},
#    '3': {'code': 'DZ',
#     'ourid': 3,
#     'source': 'https://thevirustracker.com/algeria-coronavirus-information-dz',
#     'title': 'Algeria',
#     'total_active_cases': 0,
#     'total_cases': 24872,
#     'total_deaths': 1111,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 16983,
#     'total_serious_cases': 6778,
#     'total_unresolved': 0},
#    '30': {'code': 'CL',
#     'ourid': 30,
#     'source': 'https://thevirustracker.com/chile-coronavirus-information-cl',
#     'title': 'Chile',
#     'total_active_cases': 0,
#     'total_cases': 336402,
#     'total_deaths': 8722,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 309241,
#     'total_serious_cases': 18439,
#     'total_unresolved': 0},
#    '31': {'code': 'CN',
#     'ourid': 31,
#     'source': 'https://thevirustracker.com/china-coronavirus-information-cn',
#     'title': 'China',
#     'total_active_cases': 15,
#     'total_cases': 83729,
#     'total_deaths': 4634,
#     'total_new_cases_today': 22,
#     'total_new_deaths_today': 0,
#     'total_recovered': 78855,
#     'total_serious_cases': 240,
#     'total_unresolved': 0},
#    '32': {'code': 'CO',
#     'ourid': 32,
#     'source': 'https://thevirustracker.com/colombia-coronavirus-information-co',
#     'title': 'Colombia',
#     'total_active_cases': 0,
#     'total_cases': 218428,
#     'total_deaths': 7373,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 101613,
#     'total_serious_cases': 109442,
#     'total_unresolved': 0},
#    '33': {'code': 'CG',
#     'ourid': 33,
#     'source': 'https://thevirustracker.com/congo-coronavirus-information-cg',
#     'title': 'Congo',
#     'total_active_cases': 0,
#     'total_cases': 2851,
#     'total_deaths': 50,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 666,
#     'total_serious_cases': 2135,
#     'total_unresolved': 0},
#    '34': {'code': 'CD',
#     'ourid': 34,
#     'source': 'https://thevirustracker.com/democratic-republic-of-congo-coronavirus-information-cd',
#     'title': 'Democratic Republic of Congo',
#     'total_active_cases': 0,
#     'total_cases': 0,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '35': {'code': 'CR',
#     'ourid': 35,
#     'source': 'https://thevirustracker.com/costa-rica-coronavirus-information-cr',
#     'title': 'Costa Rica',
#     'total_active_cases': 0,
#     'total_cases': 12361,
#     'total_deaths': 71,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 3322,
#     'total_serious_cases': 8968,
#     'total_unresolved': 0},
#    '36': {'code': 'CI',
#     'ourid': 36,
#     'source': 'https://thevirustracker.com/ivory-coast-coronavirus-information-ci',
#     'title': 'Ivory Coast',
#     'total_active_cases': 0,
#     'total_cases': 14733,
#     'total_deaths': 93,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 8995,
#     'total_serious_cases': 5645,
#     'total_unresolved': 0},
#    '37': {'code': 'HR',
#     'ourid': 37,
#     'source': 'https://thevirustracker.com/croatia-coronavirus-information-hr',
#     'title': 'Croatia',
#     'total_active_cases': 0,
#     'total_cases': 4530,
#     'total_deaths': 125,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 3278,
#     'total_serious_cases': 1127,
#     'total_unresolved': 0},
#    '38': {'code': 'CU',
#     'ourid': 38,
#     'source': 'https://thevirustracker.com/cuba-coronavirus-information-cu',
#     'title': 'Cuba',
#     'total_active_cases': 0,
#     'total_cases': 2462,
#     'total_deaths': 87,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 2326,
#     'total_serious_cases': 49,
#     'total_unresolved': 0},
#    '39': {'code': 'CY',
#     'ourid': 39,
#     'source': 'https://thevirustracker.com/cyprus-coronavirus-information-cy',
#     'title': 'Cyprus',
#     'total_active_cases': 0,
#     'total_cases': 1040,
#     'total_deaths': 19,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 847,
#     'total_serious_cases': 174,
#     'total_unresolved': 0},
#    '4': {'code': 'AO',
#     'ourid': 4,
#     'source': 'https://thevirustracker.com/angola-coronavirus-information-ao',
#     'title': 'Angola',
#     'total_active_cases': 0,
#     'total_cases': 812,
#     'total_deaths': 33,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 221,
#     'total_serious_cases': 558,
#     'total_unresolved': 0},
#    '40': {'code': 'CZ',
#     'ourid': 40,
#     'source': 'https://thevirustracker.com/czechia-coronavirus-information-cz',
#     'title': 'Czechia',
#     'total_active_cases': 0,
#     'total_cases': 14570,
#     'total_deaths': 364,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 9144,
#     'total_serious_cases': 5062,
#     'total_unresolved': 0},
#    '41': {'code': 'DK',
#     'ourid': 41,
#     'source': 'https://thevirustracker.com/denmark-coronavirus-information-dk',
#     'title': 'Denmark',
#     'total_active_cases': 0,
#     'total_cases': 13350,
#     'total_deaths': 611,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 12274,
#     'total_serious_cases': 465,
#     'total_unresolved': 0},
#    '42': {'code': 'DJ',
#     'ourid': 42,
#     'source': 'https://thevirustracker.com/djibouti-coronavirus-information-dj',
#     'title': 'Djibouti',
#     'total_active_cases': 0,
#     'total_cases': 5030,
#     'total_deaths': 58,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 4904,
#     'total_serious_cases': 68,
#     'total_unresolved': 0},
#    '43': {'code': 'DO',
#     'ourid': 43,
#     'source': 'https://thevirustracker.com/dominican-republic-coronavirus-information-do',
#     'title': 'Dominican Republic',
#     'total_active_cases': 0,
#     'total_cases': 56043,
#     'total_deaths': 1005,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 26466,
#     'total_serious_cases': 28572,
#     'total_unresolved': 0},
#    '44': {'code': 'EC',
#     'ourid': 44,
#     'source': 'https://thevirustracker.com/ecuador-coronavirus-information-ec',
#     'title': 'Ecuador',
#     'total_active_cases': 0,
#     'total_cases': 77257,
#     'total_deaths': 5418,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 33125,
#     'total_serious_cases': 38714,
#     'total_unresolved': 0},
#    '45': {'code': 'EG',
#     'ourid': 45,
#     'source': 'https://thevirustracker.com/egypt-coronavirus-information-eg',
#     'title': 'Egypt',
#     'total_active_cases': 0,
#     'total_cases': 89745,
#     'total_deaths': 4440,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 30075,
#     'total_serious_cases': 55230,
#     'total_unresolved': 0},
#    '46': {'code': 'SV',
#     'ourid': 46,
#     'source': 'https://thevirustracker.com/el-salvador-coronavirus-information-sv',
#     'title': 'El Salvador',
#     'total_active_cases': 32,
#     'total_cases': 12975,
#     'total_deaths': 372,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 9,
#     'total_recovered': 7151,
#     'total_serious_cases': 5452,
#     'total_unresolved': 0},
#    '47': {'code': 'GQ',
#     'ourid': 47,
#     'source': 'https://thevirustracker.com/equatorial-guinea-coronavirus-information-gq',
#     'title': 'Equatorial Guinea',
#     'total_active_cases': 0,
#     'total_cases': 3071,
#     'total_deaths': 51,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 842,
#     'total_serious_cases': 2178,
#     'total_unresolved': 0},
#    '48': {'code': 'ER',
#     'ourid': 48,
# ...
#     'ourid': 61,
#     'source': 'https://thevirustracker.com/ghana-coronavirus-information-gh',
#     'title': 'Ghana',
#     'total_active_cases': 0,
#     'total_cases': 29672,
#     'total_deaths': 153,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 26090,
#     'total_serious_cases': 3429,
#     'total_unresolved': 0},
#    '62': {'code': 'GR',
#     'ourid': 62,
#     'source': 'https://thevirustracker.com/greece-coronavirus-information-gr',
#     'title': 'Greece',
#     'total_active_cases': 0,
#     'total_cases': 4077,
#     'total_deaths': 200,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1374,
#     'total_serious_cases': 2503,
#     'total_unresolved': 0},
#    '63': {'code': 'GL',
#     'ourid': 63,
#     'source': 'https://thevirustracker.com/greenland-coronavirus-information-gl',
#     'title': 'Greenland',
#     'total_active_cases': 0,
#     'total_cases': 13,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 11,
#     'total_serious_cases': 2,
#     'total_unresolved': 0},
#    '64': {'code': 'GT',
#     'ourid': 64,
#     'source': 'https://thevirustracker.com/guatemala-coronavirus-information-gt',
#     'title': 'Guatemala',
#     'total_active_cases': 0,
#     'total_cases': 41135,
#     'total_deaths': 1573,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 27756,
#     'total_serious_cases': 11806,
#     'total_unresolved': 0},
#    '65': {'code': 'GN',
#     'ourid': 65,
#     'source': 'https://thevirustracker.com/guinea-coronavirus-information-gn',
#     'title': 'Guinea',
#     'total_active_cases': 0,
#     'total_cases': 6747,
#     'total_deaths': 41,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 5891,
#     'total_serious_cases': 815,
#     'total_unresolved': 0},
#    '66': {'code': 'GW',
#     'ourid': 66,
#     'source': 'https://thevirustracker.com/guinea-bissau-coronavirus-information-gw',
#     'title': 'Guinea-Bissau',
#     'total_active_cases': 0,
#     'total_cases': 1954,
#     'total_deaths': 26,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 803,
#     'total_serious_cases': 1125,
#     'total_unresolved': 0},
#    '67': {'code': 'GY',
#     'ourid': 67,
#     'source': 'https://thevirustracker.com/guyana-coronavirus-information-gy',
#     'title': 'Guyana',
#     'total_active_cases': 0,
#     'total_cases': 350,
#     'total_deaths': 19,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 165,
#     'total_serious_cases': 166,
#     'total_unresolved': 0},
#    '68': {'code': 'HT',
#     'ourid': 68,
#     'source': 'https://thevirustracker.com/haiti-coronavirus-information-ht',
#     'title': 'Haiti',
#     'total_active_cases': 0,
#     'total_cases': 7167,
#     'total_deaths': 154,
#     'total_new_cases_today': 21,
#     'total_new_deaths_today': 0,
#     'total_recovered': 4095,
#     'total_serious_cases': 2918,
#     'total_unresolved': 0},
#    '69': {'code': 'HN',
#     'ourid': 69,
#     'source': 'https://thevirustracker.com/honduras-coronavirus-information-hn',
#     'title': 'Honduras',
#     'total_active_cases': 171,
#     'total_cases': 36102,
#     'total_deaths': 1006,
#     'total_new_cases_today': 757,
#     'total_new_deaths_today': 18,
#     'total_recovered': 4315,
#     'total_serious_cases': 30781,
#     'total_unresolved': 0},
#    '7': {'code': 'AU',
#     'ourid': 7,
#     'source': 'https://thevirustracker.com/australia-coronavirus-information-au',
#     'title': 'Australia',
#     'total_active_cases': 3,
#     'total_cases': 13302,
#     'total_deaths': 133,
#     'total_new_cases_today': 406,
#     'total_new_deaths_today': 5,
#     'total_recovered': 8656,
#     'total_serious_cases': 4513,
#     'total_unresolved': 0},
#    '70': {'code': 'HU',
#     'ourid': 70,
#     'source': 'https://thevirustracker.com/hungary-coronavirus-information-hu',
#     'title': 'Hungary',
#     'total_active_cases': 17,
#     'total_cases': 4380,
#     'total_deaths': 596,
#     'total_new_cases_today': 14,
#     'total_new_deaths_today': 0,
#     'total_recovered': 3300,
#     'total_serious_cases': 484,
#     'total_unresolved': 0},
#    '71': {'code': 'IS',
#     'ourid': 71,
#     'source': 'https://thevirustracker.com/iceland-coronavirus-information-is',
#     'title': 'Iceland',
#     'total_active_cases': 0,
#     'total_cases': 1840,
#     'total_deaths': 10,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1822,
#     'total_serious_cases': 8,
#     'total_unresolved': 0},
#    '72': {'code': 'IN',
#     'ourid': 72,
#     'source': 'https://thevirustracker.com/india-coronavirus-information-in',
#     'title': 'India',
#     'total_active_cases': 166,
#     'total_cases': 1241416,
#     'total_deaths': 29904,
#     'total_new_cases_today': 1732,
#     'total_new_deaths_today': 14,
#     'total_recovered': 784432,
#     'total_serious_cases': 427080,
#     'total_unresolved': 0},
#    '73': {'code': 'ID',
#     'ourid': 73,
#     'source': 'https://thevirustracker.com/indonesia-coronavirus-information-id',
#     'title': 'Indonesia',
#     'total_active_cases': 0,
#     'total_cases': 91751,
#     'total_deaths': 4459,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 50255,
#     'total_serious_cases': 37037,
#     'total_unresolved': 0},
#    '74': {'code': 'IQ',
#     'ourid': 75,
#     'source': 'https://thevirustracker.com/iraq-coronavirus-information-iq',
#     'title': 'Iraq',
#     'total_active_cases': 0,
#     'total_cases': 99865,
#     'total_deaths': 4042,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 67147,
#     'total_serious_cases': 28676,
#     'total_unresolved': 0},
#    '75': {'code': 'IE',
#     'ourid': 76,
#     'source': 'https://thevirustracker.com/ireland-coronavirus-information-ie',
#     'title': 'Ireland',
#     'total_active_cases': 0,
#     'total_cases': 25819,
#     'total_deaths': 1754,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 23364,
#     'total_serious_cases': 701,
#     'total_unresolved': 0},
#    '76': {'code': 'IL',
#     'ourid': 77,
#     'source': 'https://thevirustracker.com/israel-coronavirus-information-il',
#     'title': 'Israel',
#     'total_active_cases': 250,
#     'total_cases': 56748,
#     'total_deaths': 433,
#     'total_new_cases_today': 663,
#     'total_new_deaths_today': 3,
#     'total_recovered': 23560,
#     'total_serious_cases': 32755,
#     'total_unresolved': 0},
#    '77': {'code': 'IT',
#     'ourid': 78,
#     'source': 'https://thevirustracker.com/italy-coronavirus-information-it',
#     'title': 'Italy',
#     'total_active_cases': 0,
#     'total_cases': 245032,
#     'total_deaths': 35082,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 197628,
#     'total_serious_cases': 12322,
#     'total_unresolved': 0},
#    '78': {'code': 'JM',
#     'ourid': 79,
#     'source': 'https://thevirustracker.com/jamaica-coronavirus-information-jm',
#     'title': 'Jamaica',
#     'total_active_cases': 1,
#     'total_cases': 816,
#     'total_deaths': 10,
#     'total_new_cases_today': 6,
#     'total_new_deaths_today': 0,
#     'total_recovered': 710,
#     'total_serious_cases': 96,
#     'total_unresolved': 0},
#    '79': {'code': 'JP',
#     'ourid': 80,
#     'source': 'https://thevirustracker.com/japan-coronavirus-information-jp',
#     'title': 'Japan',
#     'total_active_cases': 0,
#     'total_cases': 26303,
#     'total_deaths': 989,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 20651,
#     'total_serious_cases': 4663,
#     'total_unresolved': 0},
#    '8': {'code': 'AT',
#     'ourid': 8,
#     'source': 'https://thevirustracker.com/austria-coronavirus-information-at',
#     'title': 'Austria',
#     'total_active_cases': 0,
#     'total_cases': 19929,
#     'total_deaths': 711,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 17849,
#     'total_serious_cases': 1369,
#     'total_unresolved': 0},
#    '80': {'code': 'JO',
#     'ourid': 81,
#     'source': 'https://thevirustracker.com/jordan-coronavirus-information-jo',
#     'title': 'Jordan',
#     'total_active_cases': 0,
#     'total_cases': 1120,
#     'total_deaths': 11,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1035,
#     'total_serious_cases': 74,
#     'total_unresolved': 0},
#    '81': {'code': 'KZ',
#     'ourid': 82,
#     'source': 'https://thevirustracker.com/kazakhstan-coronavirus-information-kz',
#     'title': 'Kazakhstan',
#     'total_active_cases': 1430,
#     'total_cases': 76799,
#     'total_deaths': 585,
#     'total_new_cases_today': 1646,
#     'total_new_deaths_today': 0,
#     'total_recovered': 48220,
#     'total_serious_cases': 27994,
#     'total_unresolved': 0},
#    '82': {'code': 'KE',
#     'ourid': 83,
#     'source': 'https://thevirustracker.com/kenya-coronavirus-information-ke',
#     'title': 'Kenya',
#     'total_active_cases': 0,
#     'total_cases': 14805,
#     'total_deaths': 260,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 6757,
#     'total_serious_cases': 7788,
#     'total_unresolved': 0},
#    '83': {'code': 'KP',
#     'ourid': 84,
#     'source': 'https://thevirustracker.com/korea-coronavirus-information-kp',
#     'title': 'Korea',
#     'total_active_cases': 0,
#     'total_cases': 0,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '84': {'code': 'KR',
#     'ourid': 85,
#     'source': 'https://thevirustracker.com/south-korea-coronavirus-information-kr',
#     'title': 'South Korea',
#     'total_active_cases': 0,
#     'total_cases': 6593,
#     'total_deaths': 42,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 135,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '85': {'code': 'KW',
#     'ourid': 86,
#     'source': 'https://thevirustracker.com/kuwait-coronavirus-information-kw',
#     'title': 'Kuwait',
#     'total_active_cases': 0,
#     'total_cases': 61185,
#     'total_deaths': 417,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 51520,
#     'total_serious_cases': 9248,
#     'total_unresolved': 0},
#    '86': {'code': 'KG',
#     'ourid': 87,
#     'source': 'https://thevirustracker.com/kyrgyzstan-coronavirus-information-kg',
#     'title': 'Kyrgyzstan',
#     'total_active_cases': 1031,
#     'total_cases': 30349,
#     'total_deaths': 1169,
#     'total_new_cases_today': 990,
#     'total_new_deaths_today': 46,
#     'total_recovered': 16791,
#     'total_serious_cases': 12389,
#     'total_unresolved': 0},
#    '87': {'code': 'LA',
#     'ourid': 88,
#     'source': 'https://thevirustracker.com/lao-coronavirus-information-la',
#     'title': 'Lao',
#     'total_active_cases': 0,
#     'total_cases': 0,
#     'total_deaths': 0,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 0,
#     'total_serious_cases': 0,
#     'total_unresolved': 0},
#    '88': {'code': 'LV',
#     'ourid': 89,
#     'source': 'https://thevirustracker.com/latvia-coronavirus-information-lv',
#     'title': 'Latvia',
#     'total_active_cases': 0,
#     'total_cases': 1203,
#     'total_deaths': 31,
#     'total_new_cases_today': 6,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1045,
#     'total_serious_cases': 127,
#     'total_unresolved': 0},
#    '89': {'code': 'LB',
#     'ourid': 90,
#     'source': 'https://thevirustracker.com/lebanon-coronavirus-information-lb',
#     'title': 'Lebanon',
#     'total_active_cases': 0,
#     'total_cases': 3104,
#     'total_deaths': 43,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1607,
#     'total_serious_cases': 1454,
#     'total_unresolved': 0},
#    '9': {'code': 'AZ',
#     'ourid': 9,
#     'source': 'https://thevirustracker.com/azerbaijan-coronavirus-information-az',
#     'title': 'Azerbaijan',
#     'total_active_cases': 0,
#     'total_cases': 28633,
#     'total_deaths': 385,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 20443,
#     'total_serious_cases': 7805,
#     'total_unresolved': 0},
#    '90': {'code': 'LS',
#     'ourid': 91,
#     'source': 'https://thevirustracker.com/lesotho-coronavirus-information-ls',
#     'title': 'Lesotho',
#     'total_active_cases': 0,
#     'total_cases': 359,
#     'total_deaths': 6,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 69,
#     'total_serious_cases': 284,
#     'total_unresolved': 0},
#    '91': {'code': 'LR',
#     'ourid': 92,
#     'source': 'https://thevirustracker.com/liberia-coronavirus-information-lr',
#     'title': 'Liberia',
#     'total_active_cases': 0,
#     'total_cases': 1114,
#     'total_deaths': 70,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 592,
#     'total_serious_cases': 452,
#     'total_unresolved': 0},
#    '92': {'code': 'LY',
#     'ourid': 93,
#     'source': 'https://thevirustracker.com/libya-coronavirus-information-ly',
#     'title': 'Libya',
#     'total_active_cases': 0,
#     'total_cases': 2176,
#     'total_deaths': 53,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 489,
#     'total_serious_cases': 1634,
#     'total_unresolved': 0},
#    '93': {'code': 'LT',
#     'ourid': 94,
#     'source': 'https://thevirustracker.com/lithuania-coronavirus-information-lt',
#     'title': 'Lithuania',
#     'total_active_cases': 4,
#     'total_cases': 1960,
#     'total_deaths': 80,
#     'total_new_cases_today': 9,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1611,
#     'total_serious_cases': 269,
#     'total_unresolved': 0},
#    '94': {'code': 'LU',
#     'ourid': 95,
#     'source': 'https://thevirustracker.com/luxembourg-coronavirus-information-lu',
#     'title': 'Luxembourg',
#     'total_active_cases': 0,
#     'total_cases': 5854,
#     'total_deaths': 111,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 4530,
#     'total_serious_cases': 1213,
#     'total_unresolved': 0},
#    '95': {'code': 'MK',
#     'ourid': 96,
#     'source': 'https://thevirustracker.com/macedonia-coronavirus-information-mk',
#     'title': 'Macedonia',
#     'total_active_cases': 0,
#     'total_cases': 9547,
#     'total_deaths': 442,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 5071,
#     'total_serious_cases': 4034,
#     'total_unresolved': 0},
#    '96': {'code': 'MG',
#     'ourid': 97,
#     'source': 'https://thevirustracker.com/madagascar-coronavirus-information-mg',
#     'title': 'Madagascar',
#     'total_active_cases': 0,
#     'total_cases': 8162,
#     'total_deaths': 69,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 4662,
#     'total_serious_cases': 3431,
#     'total_unresolved': 0},
#    '97': {'code': 'MW',
#     'ourid': 98,
#     'source': 'https://thevirustracker.com/malawi-coronavirus-information-mw',
#     'title': 'Malawi',
#     'total_active_cases': 26,
#     'total_cases': 3302,
#     'total_deaths': 76,
#     'total_new_cases_today': 153,
#     'total_new_deaths_today': 5,
#     'total_recovered': 1282,
#     'total_serious_cases': 1944,
#     'total_unresolved': 0},
#    '98': {'code': 'MY',
#     'ourid': 99,
#     'source': 'https://thevirustracker.com/malaysia-coronavirus-information-my',
#     'title': 'Malaysia',
#     'total_active_cases': 0,
#     'total_cases': 8831,
#     'total_deaths': 123,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 8566,
#     'total_serious_cases': 142,
#     'total_unresolved': 0},
#    '99': {'code': 'ML',
#     'ourid': 100,
#     'source': 'https://thevirustracker.com/mali-coronavirus-information-ml',
#     'title': 'Mali',
#     'total_active_cases': 0,
#     'total_cases': 2494,
#     'total_deaths': 123,
#     'total_new_cases_today': 0,
#     'total_new_deaths_today': 0,
#     'total_recovered': 1869,
#     'total_serious_cases': 502,
#     'total_unresolved': 0},
#    'stat': 'ok'}],
#  'sitedata': [{'info': {'source': 'https://thevirustracker.com/'}}]}

# %%
country_geo = 'data/world-countries.json'
#!git clone https://git.ecdf.ed.ac.uk/mnaylor/gds_geospatial_largedatafiles.git
data = pd.read_csv('gds_geospatial_largedatafiles/Indicators.csv')

# select Life expectancy for females for all countries in 2013
# Generate a mask for Life expectancy at birth
hist_indicator =  'Life expectancy at birth, female'
mask1 = data['IndicatorName'].str.contains(hist_indicator) 

# Generate a mask for 2013 data
hist_year = 2013
mask2 = data['Year'].isin( [hist_year] )

# apply our mask
stage = data[mask1 & mask2]

#Creating a data frame with just the country codes and the values we want plotted.
data_to_plot = stage[['CountryCode','Value']]

# labelling the legend
hist_indicator = stage.iloc[0]['IndicatorName']

# Setup a folium map at a high-level zoom
map = folium.Map(location=[0, 0], zoom_start=1)

# choropleth maps bind Pandas Data Frames and json geometries.
#This allows us to quickly visualize data combinations
map.choropleth(geo_data=country_geo, data=data_to_plot,
             columns=['CountryCode', 'Value'],
             key_on='feature.id',
             fill_color='YlGnBu', fill_opacity=0.7, line_opacity=0.2,
             legend_name=hist_indicator)
# Out:
# Cloning into 'gds_geospatial_largedatafiles'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0)
# Unpacking objects: 100% (6/6), done.
# /opt/conda/lib/python3.7/site-packages/folium/folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-89fba1e23d6d> in <module>()
#      30              key_on='feature.id',
#      31              fill_color='YlGnBu', fill_opacity=0.7, line_opacity=0.2,
# ---> 32              legend_name=hist_indicator)
#
# /opt/conda/lib/python3.7/site-packages/folium/folium.py in choropleth(self, *args, **kwargs)
#     416         )
#     417         from folium.features import Choropleth
# --> 418         self.add_child(Choropleth(*args, **kwargs))
#     419
#     420     def keep_in_front(self, *args):
#
# /opt/conda/lib/python3.7/site-packages/folium/features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1154                 style_function=style_function,
#    1155                 smooth_factor=smooth_factor,
# -> 1156                 highlight_function=highlight_function if highlight else None)
#    1157
#    1158         self.add_child(self.geojson)
#
# /opt/conda/lib/python3.7/site-packages/folium/features.py in __init__(self, data, style_function, highlight_function, name, overlay, control, show, smooth_factor, tooltip, embed)
#     448         self.highlight = highlight_function is not None
#     449
# --> 450         self.data = self.process_data(data)
#     451
#     452         if self.style or self.highlight:
#
# /opt/conda/lib/python3.7/site-packages/folium/features.py in process_data(self, data)
#     483                 if not self.embed:
#     484                     self.embed_link = data
# --> 485                 with open(data) as f:
#     486                     return json.loads(f.read())
#     487         elif hasattr(data, '__geo_interface__'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/world-countries.json'

# %% [markdown]
# ## Kepler GI

# %%
# !pip install keplergl

# %%
from keplergl import KeplerGl
map_1 = KeplerGl(height=500)
map_1

# %% [markdown]
# ## Openstreetmap

# %% [markdown]
# ## Google tiles (?)

# %% [markdown]
# ## Bokeh
#
# - geospatial: https://nbviewer.jupyter.org/github/bokeh/bokeh-notebooks/blob/master/tutorial/09%20-%20Geographic%20Plots.ipynb , https://docs.bokeh.org/en/latest/docs/user_guide/geo.html#userguide-geo

# %%
import os
from bokeh.models import GMapOptions
from bokeh.plotting import gmap

map_options = GMapOptions(lat=30.2861, lng=-97.7394, map_type="roadmap", zoom=11)

# Replace the value below with your personal API key:
api_key = os.environ["GOOGLE_API_KEY"]

p = gmap(api_key, map_options, title="Austin")

data = dict(lat=[ 30.29,  30.20,  30.29],
            lon=[-97.70, -97.74, -97.78])

p.circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, source=data)

show(p)

# %% [markdown]
# tile providers: https://docs.bokeh.org/en/latest/docs/reference/tile_providers.html

# %%
import pandas as pd
population = pd.read_csv('/home/jovyan/.bokeh/data/gapminder_population.csv')
population.head()

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.tile_providers import CARTODBPOSITRON, get_provider, Vendors

output_file("tile.html")

tile_provider = get_provider(Vendors.CARTODBPOSITRON)

# range bounds supplied in web mercator coordinates
p = figure(x_range=(-2000000, 6000000), y_range=(-1000000, 7000000),
           x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(tile_provider)
show(p)
